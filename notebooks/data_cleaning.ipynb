# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/credit_transactions.csv")

df.head()
# Out:
#    user_id  year  month  day   time   amount         card_method  \
# 0        0  2015     11   15  12:55  $287.13  Online Transaction
# 1        0  2015     11   15  13:19    $2.41  Online Transaction
# 2        0  2015     11   16  09:41   $50.81  Online Transaction
# 3        0  2015     11   16  09:46  $248.36  Online Transaction
# 4        0  2015     11   16  11:20  $473.00  Online Transaction
#
#               merchant merchant_city merchant_state  ...  user_apartment  \
# 0 -8194607650924472520        ONLINE            NaN  ...             NaN
# 1 -7759074308363763111        ONLINE            NaN  ...             NaN
# 2  -551332107213382088        ONLINE            NaN  ...             NaN
# 3  4872340518840476610        ONLINE            NaN  ...             NaN
# 4 -8566951830324093739        ONLINE            NaN  ...             NaN
#
#    user_city user_state user_zip user_lat user_long user_income user_debt  \
# 0   La Verne         CA    91750    34.15   -117.76      $59696   $127613
# 1   La Verne         CA    91750    34.15   -117.76      $59696   $127613
# 2   La Verne         CA    91750    34.15   -117.76      $59696   $127613
# 3   La Verne         CA    91750    34.15   -117.76      $59696   $127613
# 4   La Verne         CA    91750    34.15   -117.76      $59696   $127613
#
#   user_rating  user_number_of_cards
# 0         787                     5
# 1         787                     5
# 2         787                     5
# 3         787                     5
# 4         787                     5
#
# [5 rows x 34 columns]

# %% [markdown]
# # Condensing Transaction Datetime

# %%
from datetime import datetime

def condense_time(row):
    x = datetime(
        int(row.year), 
        int(row.month), 
        int(row.day), 
        int(row.time.split(':')[0]), 
        int(row.time.split(':')[1])
    )
    return x

df['purchase_date'] = df.apply(condense_time, axis=1)

df.drop(columns=['year','month','day','time'], inplace=True)
# Out:
# 0       2015-11-15 12:55:00
# 1       2015-11-15 13:19:00
# 2       2015-11-16 09:41:00
# 3       2015-11-16 09:46:00
# 4       2015-11-16 11:20:00
#                 ...
# 99752   2009-10-20 08:57:00
# 99753   2015-11-30 02:45:00
# 99754   2012-01-24 17:10:00
# 99755   2015-03-11 06:14:00
# 99756   2019-01-16 09:18:00
# Name: purchase_date, Length: 99757, dtype: datetime64[ns]

# %% [markdown]
# # Fixing Dollar Amounts

# %%
df['amount'] = df['amount'].str.replace("$", "").astype(float)
# Out:
# 0        287.13
# 1          2.41
# 2         50.81
# 3        248.36
# 4        473.00
#           ...
# 99752      3.26
# 99753     30.02
# 99754     31.59
# 99755    100.00
# 99756    100.00
# Name: amount, Length: 99757, dtype: float64

# %% [markdown]
# # Adding External MCC Category Names

# %%
mcc_df = pd.read_csv('../data/mcc_grouped.csv')

def get_mcc_name(code):
    matching_code = mcc_df.loc[(mcc_df['start'] <= code) & (code <= mcc_df['end'])]
    if not matching_code.empty:
        return matching_code['Business type'].iloc[0]
    else:
        return 'Unknown'
    
# Apply the custom function to create a new column in df
df['mcc_group'] = df['mcc'].apply(get_mcc_name)

df.drop(
    columns=['mcc'], 
    inplace=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mcc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a>         return 'Unknown'
#      <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> # Apply the custom function to create a new column in df
# ---> <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> df['mcc_group'] = df['mcc'].apply(get_mcc_name)
#      <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a> df.drop(
#      <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>     columns=['mcc'],
#      <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=14'>15</a>     inplace=True
#      <a href='vscode-notebook-cell:/Users/mattd/source/0007-project/bi-project/notebooks/data_cleaning.ipynb#W1sZmlsZQ%3D%3D?line=15'>16</a> )
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'mcc'

# %%
df.dtypes
